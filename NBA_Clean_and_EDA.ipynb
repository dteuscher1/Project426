# %%
import pandas as pd
import numpy as np

# %%
season_2018 = pd.read_csv("Data/season18_19.csv")
team_2018 = pd.read_csv("Data/team18_19.csv")
season_2020 = pd.read_csv("Data/season20_21.csv")
team_2020 = pd.read_csv("Data/team20_21.csv")

# %%
all_2018 = season_2018.merge(team_2018[['GAME_ID', 'TEAM_ID', 'FGA', 'FG3A']], how = 'inner', on = ['GAME_ID', 'TEAM_ID'])

# %%
all_2020 = season_2020.merge(team_2020[['GAME_ID', 'TEAM_ID', 'FGA', 'FG3A']], how = 'inner', on = ['GAME_ID', 'TEAM_ID'])

# %%
all_data = pd.concat([all_2018, all_2020])

# %%
all_data['FG2'] = all_data['FGA'] - all_data['FG3A']

# %%
all_data.head()
test = all_data.merge(all_data, how = 'left', on = ['GAME_ID'], suffixes=('_away', '_home'))

# %%
all_data.head()
# Out:
#    Unnamed: 0   GAME_ID     TEAM_ID TEAM_NAME TEAM_ABBREVIATION  \
# 0           0  21800001  1610612755     76ers               PHI
# 1           1  21800001  1610612738   Celtics               BOS
# 2           0  21800002  1610612760   Thunder               OKC
# 3           1  21800002  1610612744  Warriors               GSW
# 4           0  21800003  1610612749     Bucks               MIL
#
#        TEAM_CITY        MINUTES  PTS  CONTESTED_SHOTS  CONTESTED_SHOTS_2PT  \
# 0   Philadelphia  240.000000:00   87               55                   31
# 1         Boston  240.000000:00  105               49                   33
# 2  Oklahoma City  240.000000:00  100               68                   49
# 3   Golden State  240.000000:00  108               68                   43
# 4      Milwaukee  240.000000:00  113               67                   39
#
#    ...  DEF_LOOSE_BALLS_RECOVERED  LOOSE_BALLS_RECOVERED  OFF_BOXOUTS  \
# 0  ...                          1                      1            4
# 1  ...                          0                      0            7
# 2  ...                          0                      0           11
# 3  ...                          1                      2            2
# 4  ...                          5                      5            5
#
#    DEF_BOXOUTS  BOX_OUT_PLAYER_TEAM_REBS  BOX_OUT_PLAYER_REBS  BOX_OUTS  FGA  \
# 0           20                         7                    2        24   87
# 1           23                        19                    6        31   97
# 2           30                        18                   10        41   91
# 3           59                        32                   11        61   95
# 4           39                        24                    6        44   85
#
#    FG3A  FG2
# 0    26   61
# 1    37   60
# 2    37   54
# 3    26   69
# 4    34   51
#
# [5 rows x 26 columns]

# %%
test.columns
# Out:
# Index(['Unnamed: 0_away', 'GAME_ID', 'TEAM_ID_away', 'TEAM_NAME_away',
#        'TEAM_ABBREVIATION_away', 'TEAM_CITY_away', 'MINUTES_away', 'PTS_away',
#        'CONTESTED_SHOTS_away', 'CONTESTED_SHOTS_2PT_away',
#        'CONTESTED_SHOTS_3PT_away', 'DEFLECTIONS_away', 'CHARGES_DRAWN_away',
#        'SCREEN_ASSISTS_away', 'SCREEN_AST_PTS_away',
#        'OFF_LOOSE_BALLS_RECOVERED_away', 'DEF_LOOSE_BALLS_RECOVERED_away',
#        'LOOSE_BALLS_RECOVERED_away', 'OFF_BOXOUTS_away', 'DEF_BOXOUTS_away',
#        'BOX_OUT_PLAYER_TEAM_REBS_away', 'BOX_OUT_PLAYER_REBS_away',
#        'BOX_OUTS_away', 'FGA_away', 'FG3A_away', 'FG2_away', 'Unnamed: 0_home',
#        'TEAM_ID_home', 'TEAM_NAME_home', 'TEAM_ABBREVIATION_home',
#        'TEAM_CITY_home', 'MINUTES_home', 'PTS_home', 'CONTESTED_SHOTS_home',
#        'CONTESTED_SHOTS_2PT_home', 'CONTESTED_SHOTS_3PT_home',
#        'DEFLECTIONS_home', 'CHARGES_DRAWN_home', 'SCREEN_ASSISTS_home',
#        'SCREEN_AST_PTS_home', 'OFF_LOOSE_BALLS_RECOVERED_home',
#        'DEF_LOOSE_BALLS_RECOVERED_home', 'LOOSE_BALLS_RECOVERED_home',
#        'OFF_BOXOUTS_home', 'DEF_BOXOUTS_home', 'BOX_OUT_PLAYER_TEAM_REBS_home',
#        'BOX_OUT_PLAYER_REBS_home', 'BOX_OUTS_home', 'FGA_home', 'FG3A_home',
#        'FG2_home'],
#       dtype='object')

# %%
test2 = test[test['TEAM_NAME_away'] != test['TEAM_NAME_home']]

# %%
test2.head()
# Out:
#    Unnamed: 0_away   GAME_ID  TEAM_ID_away TEAM_NAME_away  \
# 1                0  21800001    1610612755          76ers
# 2                1  21800001    1610612738        Celtics
# 5                0  21800002    1610612760        Thunder
# 6                1  21800002    1610612744       Warriors
# 9                0  21800003    1610612749          Bucks
#
#   TEAM_ABBREVIATION_away TEAM_CITY_away   MINUTES_away  PTS_away  \
# 1                    PHI   Philadelphia  240.000000:00        87
# 2                    BOS         Boston  240.000000:00       105
# 5                    OKC  Oklahoma City  240.000000:00       100
# 6                    GSW   Golden State  240.000000:00       108
# 9                    MIL      Milwaukee  240.000000:00       113
#
#    CONTESTED_SHOTS_away  CONTESTED_SHOTS_2PT_away  ...  \
# 1                    55                        31  ...
# 2                    49                        33  ...
# 5                    68                        49  ...
# 6                    68                        43  ...
# 9                    67                        39  ...
#
#    DEF_LOOSE_BALLS_RECOVERED_home  LOOSE_BALLS_RECOVERED_home  \
# 1                               0                           0
# 2                               1                           1
# 5                               1                           2
# 6                               0                           0
# 9                               4                           7
#
#    OFF_BOXOUTS_home  DEF_BOXOUTS_home  BOX_OUT_PLAYER_TEAM_REBS_home  \
# 1                 7                23                             19
# 2                 4                20                              7
# 5                 2                59                             32
# 6                11                30                             18
# 9                 3                31                             14
#
#    BOX_OUT_PLAYER_REBS_home  BOX_OUTS_home  FGA_home  FG3A_home  FG2_home
# 1                         6             31        97         37        60
# 2                         2             24        87         26        61
# 5                        11             61        95         26        69
# 6                        10             41        91         37        54
# 9                         4             34        92         38        54
#
# [5 rows x 51 columns]

# %%
test3 = test2[test2.duplicated(subset = 'GAME_ID') == False]
test3['CONTEST_SHOT_RATE_away'] = test3['CONTESTED_SHOTS_away']/test3['FGA_home']
test3['CONTEST_SHOT_RATE_home'] = test3['CONTESTED_SHOTS_home']/test3['FGA_away']
test3['PT_DIFF'] = test3['PTS_away'] - test3['PTS_home']
# Out:
# /Users/davidteuscher/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/davidteuscher/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/davidteuscher/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
test3.head()
# Out:
#     Unnamed: 0_away   GAME_ID  TEAM_ID_away TEAM_NAME_away  \
# 1                 0  21800001    1610612755          76ers
# 5                 0  21800002    1610612760        Thunder
# 9                 0  21800003    1610612749          Bucks
# 13                0  21800004    1610612751           Nets
# 17                0  21800005    1610612763      Grizzlies
#
#    TEAM_ABBREVIATION_away TEAM_CITY_away   MINUTES_away  PTS_away  \
# 1                     PHI   Philadelphia  240.000000:00        87
# 5                     OKC  Oklahoma City  240.000000:00       100
# 9                     MIL      Milwaukee  240.000000:00       113
# 13                    BKN       Brooklyn  240.000000:00       100
# 17                    MEM        Memphis  240.000000:00        83
#
#     CONTESTED_SHOTS_away  CONTESTED_SHOTS_2PT_away  ...  DEF_BOXOUTS_home  \
# 1                     55                        31  ...                23
# 5                     68                        49  ...                59
# 9                     67                        39  ...                31
# 13                    61                        46  ...                23
# 17                    57                        35  ...                33
#
#     BOX_OUT_PLAYER_TEAM_REBS_home  BOX_OUT_PLAYER_REBS_home  BOX_OUTS_home  \
# 1                              19                         6             31
# 5                              32                        11             61
# 9                              14                         4             34
# 13                             16                        11             27
# 17                             22                         9             43
#
#     FGA_home  FG3A_home  FG2_home  CONTEST_SHOT_RATE_away  \
# 1         97         37        60                0.567010
# 5         95         26        69                0.715789
# 9         92         38        54                0.728261
# 13        92         24        68                0.663043
# 17        83         26        57                0.686747
#
#     CONTEST_SHOT_RATE_home  PT_DIFF
# 1                 0.563218      -18
# 5                 0.747253       -8
# 9                 0.811765        1
# 13                0.585366       -3
# 17                0.690476      -28
#
# [5 rows x 54 columns]

# %%
all_data.groupby(['GAME_ID'])['PTS']
